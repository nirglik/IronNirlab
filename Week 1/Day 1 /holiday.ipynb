# %% [markdown]
# I created this notebook in order to share my favourite vacation destination

# %% [markdown]
# This is me, dreaming about my number 1 holiday spot

# %% [markdown]
# ![NIR.jpg](attachment:NIR.jpg)

# %% [markdown]
# My number 1 destination is Amafli Coast. I like it because:
# - The beach
# - The food
# - The landscape

# %% [markdown]
# ![Amalfi.png](attachment:Amalfi.png)

# %%
#Here I used the input function in order to ask for a name and added a Hi and name
user_name = input("Enter your name:- ")
print("Hi,", user_name, "\b!")
# Out:
# Enter your name:- Nir
# Hi, Nir!

# %%
#Here I imported the option to display videos
from IPython.display import HTML

# %%
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/1rx9dWL6cAc?start=190" frameborder="0" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/1rx9dWL6cAc?start=190" frameborder="0" allowfullscreen></iframe>
